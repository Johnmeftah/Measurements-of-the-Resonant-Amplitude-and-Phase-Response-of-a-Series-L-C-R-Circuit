# %%
import matplotlib.pyplot as plt

# f0_peak_exp and peak_amp values

f0_peak_exp = [
        14520.1, 4116.1, 2895.8, 2895.8, 1827.76, 1286.5, 909.88 
    ]

sqrt_1_c = [
        16012.81538, 4472.135955, 3162.27766, 3162.27766, 2000, 1414.213562, 1000
    ]



# Plotting the graph
plt.figure(figsize=(10, 5))
plt.plot(f0_peak_exp, sqrt_1_c, marker='o', linestyle='-')
plt.title('Resonance Frequency (f0) vs sqrt (1/C)')
plt.xlabel('√(1/c)')
plt.ylabel('f(0) exp')
plt.grid(True)
plt.savefig("plot_3.png", dpi=500)
plt.show()
