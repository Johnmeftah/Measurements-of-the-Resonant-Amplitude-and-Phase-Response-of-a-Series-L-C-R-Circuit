# %%
import matplotlib.pyplot as plt

# Frequency and peak amplitude values
frequency = [
    3000, 3250, 3500, 3750, 3900, 3910, 3920, 3930, 3940, 3950, 3960, 3970, 3980,
    3990, 4000, 4010, 4020, 4030, 4040, 4050, 4060, 4070, 4080, 4090, 4100, 4110,
    4120, 4130, 4140, 4150, 4160, 4170, 4180, 4190, 4200, 4225, 4250, 4275, 4300,
    4325, 4350, 4375, 4400, 4500, 4550, 4650, 4700, 4750, 4800, 4850, 4900, 5000,
    5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000
]

peak_amp = [
    2.124277457, 2.622478386, 3.518731988, 5.622478386, 9.267241379, 9.324712644,
    9.818443804, 10.44606414, 10.91304348, 11.28653295, 12.02586207, 12.6, 13.51304348,
    14.52616279, 15.47142857, 16.45272206, 18.22636103, 21.1030303, 23.47239264, 24.26210826,
    27.5042735, 31.80924855, 36.2816092, 42.35755814, 47.39942529, 51.65116279, 52.95266272,
    52.25970149, 48.16816817, 44.2560241, 40.76160991, 35.43674699, 31.48338369, 28.29552239,
    25.48511905, 20.28228228, 16.51632047, 13.74486804, 11.9380531, 10.35380117, 9.183673469,
    8.302052786, 7.439882698, 5.416909621, 4.819526627, 3.779069767, 3.430232558, 3.117647059,
    2.913946588, 2.67251462, 2.498533724, 2.156976744, 1.60058309, 1.326409496, 1.043731778,
    0.909356725, 0.780701754, 0.683284457, 0.613095238, 0.525222552
]

# Plotting the graph
plt.figure(figsize=(10, 5))
plt.plot(frequency, peak_amp, marker='o', linestyle='-')
plt.title('Frequency vs Peak Amplitude')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Peak Amp (B/A)')
plt.grid(True)
plt.savefig("plot_1.png", dpi=500)
plt.show()
