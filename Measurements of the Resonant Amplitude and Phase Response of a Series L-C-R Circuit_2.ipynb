# %%
import matplotlib.pyplot as plt

# Frequency and peak amplitude values

frequency = [
        3000, 3025, 3050, 3075, 3100, 3200, 3300, 3400, 3500, 3600, 3700,
        3800, 3900, 4000, 4025, 4050, 4075, 4100, 4200, 4300, 4400, 4500,
        4600, 4700, 4800, 4900, 5000, 5250, 5500, 5750, 6000, 6250, 6500,
        6750, 7000
    ]

peak_amp = [
        2.100864553, 2.162790698, 2.235294118, 2.207492795, 2.25648415, 2.461095101,
        2.706051873, 3.176291793, 3.423631124, 4.067647059, 4.771014493, 5.83908046,
        7.709302326, 10.42363112, 11.23768116, 12.04322767, 13.01764706, 13.34011628,
        12.20821114, 8.85131953, 6.526315789, 4.93877551, 3.997084548, 3.25872093,
        2.762463343, 2.450742669, 2.143274854, 1.641176471, 1.295321637, 1.091445428,
        0.916666667, 0.773255814, 0.680232558, 0.622354695, 0.544378698
    ]



# Plotting the graph
plt.figure(figsize=(10, 5))
plt.plot(frequency, peak_amp, marker='o', linestyle='-')
plt.title('Frequency vs Peak Amplitude')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Peak Amp (B/A)')
plt.grid(True)
plt.savefig("plot_2.png", dpi=500)
plt.show()
