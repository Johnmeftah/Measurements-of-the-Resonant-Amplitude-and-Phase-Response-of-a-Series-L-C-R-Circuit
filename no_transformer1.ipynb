# %%
import matplotlib.pyplot as plt

# f0_peak_exp and peak_amp values

freq_hz = [
3000,
3250,
3500,
3750,
3900,
3910,
3920,
3930,
3940,
3950,
3960,
3970,
3980,
3990,
4000,
4010,
4020,
4030,
4040,
4050,
4060,
4070,
4080,
4090,
4100,
4110,
4120,
4130,
4140,
4150,
4160,
4170,
4180,
4190,
4200,
4225,
4250,
4275,
4300,
4325,
4350,
4375,
4400,
4500,
4550,
4650,
4700,
4750,
4800,
4850,
4900,
5000,
5250,
5500,
5750,
6000,
6250,
6500,
6750,
7000,
    ]

peak_amp = [
2.138,
2.755,
3.498,
5.714,
9.464,
9.667,
10.302,
10.684,
11.274,
11.907,
12.700,
13.353,
14.294,
15.271,
16.794,
17.963,
19.428,
21.113,
23.323,
25.588,
28.551,
32.735,
32.863,
43.660,
47.733,
51.397,
54.586,
52.175,
48.715,
44.212,
39.659,
35.543,
31.532,
28.459,
25.869,
18.288,
15.331,
13.159,
11.288,
10.063,
8.992,
8.080,
7.386,
5.380,
4.742,
3.777,
3.328,
3.115,
2.858,
2.715,
2.495,
2.173,
1.651,
1.265,
1.074,
0.866,
0.779,
0.678,
0.597,
0.516,
    ]

# Plotting the graph
plt.figure(figsize=(10, 5))
plt.plot(freq_hz, peak_amp, marker='o', linestyle='-')
plt.title('Frequency Vs. Peak Amplitude No transformer (R=5 and C =0.05)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Vb/Va')
plt.grid(True)
plt.savefig("plot_6.png", dpi=500)
plt.show()
